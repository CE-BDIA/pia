# %%
import pandas as pd

reviews = pd.read_csv("../../data/winemag-data-130k-v2.csv", index_col=0)

# %% [markdown]
# # Exercisis
#
# Visualitzeu les primeres línies de les vostres dades executant la cel·la següent:

# %%
reviews.head()

# %% [markdown]
# ## 1.
# `region_1` i `region_2` són noms poc informatius per a les columnes regionals del conjunt de dades.
#
# Creeu una còpia de les `reviews` amb aquestes columnes canviades de nom a `region` i `locale`, respectivament.

# %% [markdown]
# ## 2.
# Establiu el nom de l'índex al conjunt de dades a `wines`.

# %% [markdown]
# ## 3.
# El conjunt de dades [Things on Reddit](https://www.kaggle.com/residentmario/things-on-reddit/data) inclou enllaços de productes d'una selecció de fòrums millor classificats (*subreddits*) a reddit.com. Executeu la cel·la següent per carregar un DataFrame dels productes esmentats al subreddit */r/gaming* i un altre per als productes esmentats al subreddit *r//movies*.

# %%
gaming_products = pd.read_csv("data/gaming.csv")
gaming_products['subreddit'] = "r/gaming"
movie_products = pd.read_csv("data/movies.csv")
movie_products['subreddit'] = "r/movies"

# %% [markdown]
# Crea un `DataFrame` de productes que apareixen a *tots* els subreddits.
