# %% [markdown]
# **This notebook is an exercise in the [Pandas](https://www.kaggle.com/learn/pandas) course.  You can reference the tutorial at [this link](https://www.kaggle.com/residentmario/indexing-selecting-assigning).**
#
# ---

# %% [markdown]
# ## Introducció
#
# En este exercici utilitzarem un DataSet amb informació de [vins](https://www.kaggle.com/datasets/zynicide/wine-reviews).

# %% [markdown]
# ### Pregunta 1
#
# Descarrega el DataSet i carrega'l. Guarda el resultat a una variable `reviews`.

# %% [markdown]
# ### Pregunta 2
#
# Fes-te una imatge general de quina informació conté el DataSet mostrant les primeres cinc línies.

# %% [markdown]
# ### Pregunta 3
#
# Selecciona la columna `description` i asigna el resultat a una variable `desc`.

# %% [markdown]
# ### Pregunta 4
#
# Quin tipus d'objecte és `desc`?

# %% [markdown]
# ### Pregunta 5
#
# Selecciona el primer valor de descripció i assigna'l a la variable `first_description`.

# %% [markdown]
# ### Pregunta 6
#
# Selecciona la primera fila de `reviews` i assigna el valor a `first_row`.

# %% [markdown]
# ### Pregunta 7
#
# Selecciona els primers 10 valors de `description` i assigna el resultat a `first_descriptions`. Hauries de construir una Serie de Pandas.

# %% [markdown]
# ### Pregunta 8
#
# Selecciona els registres amb índex `1`, `2`, `3`, `5`, i `8`, i assigna els resultats a una variable `sample_reviews`.
#
# El resultat hauria de ser el següent:
#
# ![](https://storage.googleapis.com/kaggle-media/learn/images/sHZvI1O.png)

# %% [markdown]
# ### Pregunta 9
#
# Crea una variable `df` que continga les coliumnes `country`, `province`, `region_1`, i `region_2` dels registres amb índex `0`, `1`, `10`, and `100`.
#
# ![](https://storage.googleapis.com/kaggle-media/learn/images/FUCGiKP.png)

# %% [markdown]
# ### Pregunta 10
#
# Crea una variable `df` que continga `country` i `variety` dels primers 100 registres.
#
# Recorda que:
#
# > `iloc` on el primer element s'inclou però l'últim no.
# `loc`, inclou el primer i l'últim elements.

# %% [markdown]
# ### Pregunta 11
#
# Crea un DataFrame `spanish_wines` que continga els vins espanyols.

# %% [markdown]
# ### Pregunta 12
#
# Crea un DataFrame `top_oceania_wines` que continga els vins australians i de Nova Zelanda amb almenys 95 punts.
